# %%
# primary settings
state = 'AL'
level = 'tract'
deviation = 0.01  # 1.00%

# %%
filepath = 'C:\\districting-data-2020\\'
filename = 'ALplanD.csv'
    
# read the file
from tract_approximation import read_block_assignment_file
block_assignment = read_block_assignment_file(filepath, filename)
print("#blocks read:",len(block_assignment))
# Out:
# #blocks read: 185976

# %%
from gerrychain import Graph
filepath = 'C:\\districting-data-2020\\'

# get block-level graph
filename = state + '_block.json'
GB = Graph.from_json( filepath + filename )
for node in GB.nodes:
    GB.nodes[node]['TOTPOP'] = GB.nodes[node]['P0010001']
    
# get tract-level graph
filename = state + '_tract.json'
G = Graph.from_json( filepath + filename )
for node in G.nodes:
    G.nodes[node]['TOTPOP'] = G.nodes[node]['P0010001']
    
import networkx as nx
print("Are block-level and tract-level graphs connected?", nx.is_connected(GB), nx.is_connected(G) )
# Out:
# Are block-level and tract-level graphs connected? True True

# %%
from number_of_districts import congressional_districts_2020
k = congressional_districts_2020[state]

import math
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k
L = math.ceil( ( 1 - deviation / 2 ) * ideal_population )
U = math.floor(( 1 + deviation / 2 ) * ideal_population )

print("Using k, L, U", k, L, U)
# Out:
# Using k, L, U 7 714166 721342

# %%
from tract_approximation import get_tract_approximation
tract_districts = get_tract_approximation(G, GB, L, U, k, block_assignment)
# Out:
# Initial block-level plan:
# # 	 population 	 connected?
# 0 	 717755 	 True
# 1 	 717754 	 True
# 2 	 717754 	 True
# 3 	 717754 	 True
# 4 	 717754 	 True
# 5 	 717754 	 True
# 6 	 717754 	 True
# min, max pop: 717754 717755
# total deviation = 1
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-27
# Set parameter MIPGap to value 0
# Set parameter IntFeasTol to value 1e-07
# Set parameter FeasibilityTol to value 1e-07
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1451 rows, 10059 columns and 30135 nonzeros
# Model fingerprint: 0x6f273ad2
# Variable types: 0 continuous, 10059 integer (10059 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 2e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve time: 0.02s
# Presolved: 1451 rows, 10059 columns, 30135 nonzeros
# Variable types: 0 continuous, 10059 integer (10059 binary)
#
# Root relaxation: objective 1.224022e+05, 371 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 122402.192    0    2          - 122402.192      -     -    1s
# H    0     0                    123523.00000 122402.192  0.91%     -    1s
# H    0     0                    123448.00000 122402.192  0.85%     -    1s
#      0     0     cutoff    0      123448.000 123448.000  0.00%     -    1s
#
# Cutting planes:
#   Cover: 1
#   StrongCG: 1
#   Lazy constraints: 3
#
# Explored 1 nodes (372 simplex iterations) in 1.17 seconds (0.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 123448 123523
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.234480000000e+05, best bound 1.234480000000e+05, gap 0.0000%
#
# User-callback calls 136, time in user-callback 1.08 sec
# Final tract-level approximate plan:
# # 	 population 	 connected?
# 0 	 717820 	 True
# 1 	 718017 	 True
# 2 	 719974 	 True
# 3 	 715525 	 True
# 4 	 717221 	 True
# 5 	 718464 	 True
# 6 	 717258 	 True
# min, max pop: 715525 719974
# total deviation = 4449

# %%
print("tract_districts =",tract_districts)
# Out:
# tract_districts = [[0, 43, 44, 46, 48, 49, 59, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 88, 232, 233, 266, 267, 268, 357, 358, 375, 376, 441, 443, 446, 453, 454, 456, 458, 459, 460, 461, 462, 463, 464, 467, 579, 580, 581, 582, 583, 584, 585, 586, 602, 603, 604, 605, 613, 614, 615, 620, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 764, 765, 783, 784, 785, 786, 787, 788, 789, 790, 806, 808, 809, 810, 812, 813, 814, 815, 817, 818, 821, 904, 905, 906, 907, 908, 909, 910, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 1038, 1039, 1040, 1041, 1070, 1071, 1072, 1073, 1074, 1075, 1129, 1130, 1131, 1132, 1162, 1163, 1174, 1181, 1182, 1192, 1193, 1240, 1241, 1243, 1244, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1261, 1262, 1284, 1285, 1286, 1287, 1318, 1319, 1320, 1321, 1322, 1323, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436], [8, 9, 10, 37, 38, 39, 40, 45, 47, 50, 51, 53, 54, 55, 56, 57, 58, 60, 80, 82, 84, 97, 98, 99, 100, 116, 154, 155, 156, 157, 158, 159, 160, 161, 270, 298, 316, 317, 318, 319, 320, 321, 336, 341, 342, 343, 344, 345, 350, 351, 352, 353, 354, 355, 356, 359, 360, 369, 373, 374, 377, 379, 380, 407, 408, 409, 410, 411, 412, 413, 414, 415, 428, 429, 430, 431, 432, 433, 435, 436, 437, 438, 442, 447, 448, 449, 450, 451, 452, 455, 457, 465, 466, 468, 473, 475, 476, 477, 478, 505, 506, 507, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 574, 575, 576, 577, 578, 587, 588, 589, 590, 591, 606, 607, 608, 609, 623, 624, 625, 626, 627, 628, 629, 630, 688, 722, 728, 729, 730, 731, 732, 733, 777, 778, 