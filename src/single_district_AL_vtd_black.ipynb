# %%
# primary settings
state = 'AL'
district_type = 'CD'
level = 'vtd'
deviation = 0.01  # 0.10 means 10% means +/-5%
minority = 'Black'

# %%
filepath = 'C:\\districting-data-2020\\'
filename = state + '_' + level + '.json'

from read import read_graph_from_json
G = read_graph_from_json( filepath + filename )

# total population
for i in G.nodes:
    G.nodes[i]['TOTPOP'] = G.nodes[i]['P0010001'] 
    
print("number of nodes, edges:",G.number_of_nodes(),G.number_of_edges())
# Out:
# number of nodes, edges: 1837 5221

# %%
from number_of_districts import number_of_districts

k = number_of_districts[state, district_type]
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
L = math.ceil(  ideal_population * (1-deviation/2) )
U = math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 7 714166 721342

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, contiguity='cut', split_counties_limit=1 )
# Out:
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 11 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2024-05-11
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14192 rows, 12486 columns and 58701 nonzeros
# Model fingerprint: 0xa78f52bc
# Model has 1 quadratic constraint
# Variable types: 6 continuous, 12480 integer (12480 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 3e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.23s
# Presolved: 14190 rows, 12485 columns, 58696 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 12482 integer (12480 binary)
#
# Root relaxation: objective 0.000000e+00, 6806 iterations, 1.50 seconds (0.55 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   91          -    0.00000      -     -    4s
#      0     0    1.04065    0 1076          -    1.04065      -     -   13s
#      0     0    1.07090    0 1057          -    1.07090      -     -   15s
#      0     0    1.07977    0 1067          -    1.07977      -     -   16s
#      0     0    1.08301    0 1067          -    1.08301      -     -   17s
#      0     0    1.08301    0 1067          -    1.08301      -     -   18s
#      0     2    1.08367    0 1067          -    1.08367      -     -   22s
#      3     8    1.29385    2 1112          -    1.29340      -  1289   26s
#     15    20    1.69939    4 1039          -    1.38230      -   800   30s
#     33    40    1.86924    7  423          -    1.38230      -   825   35s
#     63    69    2.23750   11  840          -    1.38230      -   710   40s
#     86    92    2.43413   15  840          -    1.38230      -   678   45s
#    132   144    2.91970   20  729          -    1.38230      -   591   50s
#    190   197    3.72787   28  468          -    1.38230      -   549   55s
#    253   276    4.82903   37  415          -    1.38230      -   506   61s
#    428   492    5.49117   70  225          -    1.38230      -   359   65s
#    668   652   10.86486   99  214          -    1.38230      -   267   70s
#    688   665   11.13270  104  281          -    1.38230      -   275   76s
#    718   703 infeasible  112               -    1.45469      -   277   82s
#    780   782 infeasible    6               -    1.45469      -   276   85s
#    926   903    3.94524   16  118          -    1.45469      -   259   91s
#    981   944    4.21907   22  108          -    1.45469      -   265   95s
#   1041  1006    4.22979   28   89          -    1.45469      -   268  100s
#   1166  1173    4.27659   58   13          -    1.45469      -   261  106s
#   1324  1271 infeasible   79               -    1.49997      -   249  111s
#   1417  1274    3.05671   32 1074          -    1.49997      -   239  119s
#   1418  1275   17.16825  172 1068          -    1.49997      -   239  123s
#   1419  1276    4.20923   83 1069          -    1.49997      -   239  127s
#   1420  1276    4.67809   15 1070          -    1.49997      -   239  130s
#   1422  1278   17.08963  192 1094          -    1.49997      -   238  135s
#   1424  1279    2.60766    8 1095          -    1.49997      -   238  144s
#   1425  1280   18.17698  227 1095          -    1.49997      -   238  146s
#   1426  1280   10.84247   98 1095          -    1.49997      -   238  152s
#   1427  1284    1.49997   16 1112          -    1.49997      -   248  158s
#   1429  1287    1.49997   17 1059          -    1.49997      -   250  160s
#   1441  1295    1.73002   19  958          -    1.57748      -   257  165s
#   1453  1303    1.96847   20  639          -    1.61891      -   264  171s
#   1466  1313    2.65025   22  603          -    1.66288      -   273  177s
#   1486  1329    3.06162   23  179          -    1.66288      -   277  181s
#   1522  1350    2.66315   27   52          -    1.66288      -   280  185s
#   1564  1381    2.68966   35  264          -    1.66288      -   290  190s
#   1599  1409    2.68991   38  101          -    1.66288      -   295  195s
#   1666  1460    2.69012   43   33          -    1.66288      -   300  200s
#   1742  1508    2.70205   51  215          -    1.66288      -   311  206s
#   1825  1560    2.70211   57  111          -    1.66288      -   316  210s
#   1940  1643    6.70260   63  135          -    1.66288      -   316  215s
#   2028  1668    2.70226   69   62          -    1.66288      -   324  221s
#   2105  1732    2.70234   75   59          -    1.66288      -   327  225s
#   2202  1815    2.70239   81   37          -    1.66288      -   329  230s
#   2355  1918    2.70254   95  114          -    1.66288      -   325  235s
#   2572  2072    2.70697  105  231          -    1.66288      -   316  240s
#   2783  2078    2.70749  116  218          -    1.66288      -   310  248s
#   2813  2109    2.70762  123   12          -    1.66288      -   315  250s
# H 2817  1021                       2.7433500    1.66288  39.4%   315  250s
#   2942   976    2.70824  156   60    2.74335    1.66288  39.4%   310  256s
# H 3112   855                       2.6137683    1.80185  31.1%   300  259s
#   3151   820    2.23652   20 1168    2.61377    1.80185  31.1%   298  263s
# H 3172   755                       2.5890644    1.80185  30.4%   298  263s
#   3205   749    2.45375   22  501    2.58906    1.80185  30.4%   296  267s
#   3283   733    2.48563   29 1022    2.58906    1.80185  30.4%   293  271s
#   3426   743    2.54454   44   29    2.58906    2.42102  6.49%   285  275s
# H 3547   647                       2.5533458    2.42111  5.18%   278  275s
#   3776   652    2.51848   29   43    2.55335    2.47858  2.93%   267  282s
# H 3959   539                       2.5356450    2.48093  2.16%   257  282s
#   4077   526    2.49482   37 1010    2.53564    2.48620  1.95%   250  285s
# H 4196   416                       2.5331828    2.48620  1.85%   245  285s
# * 4306   384             162       2.5294134    2.48898  1.60%   240  285s
# * 4440   373             163       2.5261549    2.49536  1.22%   233  286s
#   4525   421     cutoff   50         2.52615    2.49956  1.05%   230  290s
#   5528    64    2.52301   29  152    2.52615    2.51352  0.50%   196  296s
#
# Cutting planes:
#   Gomory: 6
#   MIR: 5
#   Flow cover: 3
#   Lazy constraints: 13
#
# Explored 5938 nodes (1122451 simplex iterations) in 297.91 seconds (154.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2.52615 2.52941 2.53318 ... 2.74335
#
# Optimal solution found (tolerance 0.00e+00)
# Warning: max constraint violation (1.1040e-07) exceeds tolerance
# Best objective 2.526154917620e+00, best bound 2.526154917620e+00, gap 0.0000%
#
# User-callback calls 21507, time in user-callback 0.92 sec

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 2.5261549176200297
# The Polsby-Popper score is 0.3958585409885042
#
# District has this many nodes: 390
# And a population of: 719460
# Is it connected? True

# %%
vap = sum( DG.nodes[i]['VAP'] for i in district )
mvap = sum( DG.nodes[i]['MVAP'] for i in district )
print("The total voting age population is:",vap)
print("Among the",minority,"population, the VAP is:",mvap)
print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 564042
# Among the Black population, the VAP is: 282033
# As a percentage, this is 50.0 %

# %%
# Let's draw the district on a map
from export import draw_single_district
G._state = state
G._level = level

# %%
# State-wide view
draw_single_district( G, district, zoom=False )
# Out:
# Exporting to png...

# %%
# District-only view
draw_single_district( G, district, zoom=True )
# Out:
# Exporting to png...

# %%
complement = [ i for i in G.nodes if i not in district ]
print("Is the complement connected?", nx.is_connected(G.subgraph(complement)))

print("Sizes of components:")
for component in nx.connected_components(G.subgraph(complement)):
    print(len(component))
# Out:
# Sizes of components:
# 1446
# 1

# %%
m = build_single_district_mip( DG, minority=minority, contiguity='cut', split_counties_limit=1, complement_contiguity='cut')
# Out:
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 14192 rows, 12486 columns and 58701 nonzeros
# Model fingerprint: 0xa78f52bc
# Model has 1 quadratic constraint
# Variable types: 6 continuous, 12480 integer (12480 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 3e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.17s
# Presolved: 14190 rows, 12485 columns, 58696 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 12482 integer (12480 binary)
#
# Root relaxation: objective 0.000000e+00, 6806 iterations, 0.48 seconds (0.55 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   91          -    0.00000      -     -    1s
#      0     0    1.04065    0 1076          -    1.04065      -     -    6s
#      0     0    1.07090    0 1057          -    1.07090      -     -    7s
#      0     0    1.07977    0 1067          -    1.07977      -     -    7s
#      0     0    1.08301    0 1067          -    1.08301      -     -    8s
#      0     0    1.08301    0 1067          -    1.08301      -     -    9s
#      0     2    1.08367    0 1067          -    1.08367      -     -   11s
#      7    12    1.66173    3 1246          -    1.29558      -  1166   15s
#     45    50 infeasible    9               -    1.38230      -   719   20s
#     78    85    2.35854   14  836          -    1.38230      -   687   25s
#    147   160    3.15451   22  491          -    1.38230      -   565   30s
#    380   418    5.33216   61  225          -    1.38230      -   386   35s
#    688   665   11.13270  104  281          -    1.38230      -   275   42s
#    742   739    3.42310    4  169          -    1.45469      -   280   46s
#    919   904    3.92780   15  188          -    1.45469      -   262   50s
#   1016   978    4.29080   25   24          -    1.45469      -   266   55s
#   1151  1185    4.27659   46   13          -    1.45469      -   265   61s
#   1410  1319    4.46090   44 1074          -    1.45469      -   242   70s
#   1412  1321    5.60791   29 1069          -    1.45469      -   241   75s
#   1414  1322    3.04863   28 1094          -    1.45469      -   241   81s
#   1416  1323    5.93267   87 1094          -    1.45469      -   241   85s
#   1427  1336    2.55382   17  578          -    1.65042      -   257   90s
#   1443  1346    2.68303   19 1189          -    1.68895      -   265   95s
#   1468  1367    3.05248   22 1119          -    2.04020      -   271  100s
#   1515  1402    3.16221   26  602          -    2.14337      -   277  105s
#   1545  1424    4.00366   28  399          -    2.14337      -   284  110s
#   1600  1466    4.22540   30 1217          -    2.14337      -   291  115s
#   1648  1480    3.79021   32 1201          -    2.14337      -   299  120s
#   1695  1514    4.30253   38  878          -    2.14337      -   310  126s
#   1767  1567    4.33039   45  407          -    2.14337      -   322  130s
#   1941  1696    4.35373   56  444          -    2.14337      -   325  135s
#   2148  1827    4.37586   71   69          -    2.14337      -   321  140s
#   2378  1928    4.45721   95   36          -    2.14337      -   323  145s
#   2626  2048    4.46404  123  126          -    2.14337      -   315  151s
#   2771  2061    2.88078   29   28          -    2.24323      -   310  156s
#   2861  2156    2.89462   44   88          -    2.24323      -   308  161s
#   2940  2181    2.90319   50   93          -    2.24323      -   304  167s
#   3173  2493    2.91459   96   25          -    2.24323      -   291  171s
#   3611  2701    2.93683  134   21          -    2.24323      -   272  176s
#   3939  2772 infeasible  180               -    2.33644      -   266  182s
#   4237  2914    3.35394   25  546          -    2.33644      -   259  187s
# H 4312   902                       3.1477648    2.33644  25.8%   258  187s
#   4313   886     cutoff   28         3.14776    2.35006  25.3%   258  190s
# H 4317   813                       3.1320546    2.35006  25.0%   258  190s
# H 4342   651                       2.9536022    2.37125  19.7%   259  190s
#   4424   678 infeasible   21         2.95360    2.41673  18.2%   259  197s
# H 4430   564                       2.9202968    2.41673  17.2%   259  197s
#   4478   608    2.88038   22   80    2.92030    2.45541  15.9%   260  200s
# H 4546   470                       2.8911163    2.45541  15.1%   258  200s
# H 4594   361                       2.6223367    2.45541  6.37%   258  203s
#   4704   417     cutoff   48         2.62234    2.45708  6.30%   253  207s
# H 4917   387                       2.5850068    2.46058  4.81%   246  207s
#   4943   436    2.51822   28   25    2.58501    2.46058  4.81%   246  211s
# H 4944   413                       2.5329658    2.46058  2.86%   246  211s
#   5233   278     cutoff   78         2.53297    2.46912  2.52%   237  215s
#   6370   442    2.52905   42   20    2.53297    2.49978  1.31%   205  223s
#   7119   407    2.52438   64   16    2.53297    2.51409  0.75%   188  228s
# * 7289   359              50       2.5279456    2.51409  0.55%   185  228s
#   7800   116     cutoff   30         2.52795    2.51777  0.40%   176  230s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 1
#   MIR: 5
#   Flow cover: 3
#   Lazy constraints: 43
#
# Explored 8242 nodes (1408677 simplex iterations) in 231.02 seconds (182.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 2.52795 2.53297 2.58501 ... 3.14776
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.527945607256e+00, best bound 2.527945607256e+00, gap 0.0000%
#
# User-callback calls 25865, time in user-callback 3.10 sec

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 2.5279456072560302
# The Polsby-Popper score is 0.39557813155855615
#
# District has this many nodes: 389
# And a population of: 718803
# Is it connected? True

# %%
vap = sum( DG.nodes[i]['VAP'] for i in district )
mvap = sum( DG.nodes[i]['MVAP'] for i in district )
print("The total voting age population is:",vap)
print("Among the",minority,"population, the VAP is:",mvap)
print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 564639
# Among the Black population, the VAP is: 282324
# As a percentage, this is 50.0 %

# %%
draw_single_district( G, district, zoom=False )
# Out:
# Exporting to png...

# %%
draw_single_district( G, district, zoom=True )
# Out:
# Exporting to png...

# %%
complement = [ i for i in G.nodes if i not in district ]
print("Is the complement connected?", nx.is_connected(G.subgraph(complement)))
# Out:
# Is the complement connected? True
