# %%
# primary settings
state = 'AL'
district_type = 'CD'
level = 'vtd'
deviation = 0.001  # 0.10 means 10% means +/-5%
minority = 'Black'

# %%
filepath = 'C:\\districting-data-2020\\'
filename = state + '_' + level + '.json'

from read import read_graph_from_json
G = read_graph_from_json( filepath + filename )

# total population
for i in G.nodes:
    G.nodes[i]['TOTPOP'] = G.nodes[i]['P0010001'] 
    
print("number of nodes, edges:",G.number_of_nodes(),G.number_of_edges())
# Out:
# number of nodes, edges: 1837 5221

# %%
from number_of_districts import number_of_districts

k = number_of_districts[state, district_type]
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
L = math.ceil(  ideal_population * (1-deviation/2) )
U = math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 7 717396 718113

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, contiguity='cut', split_counties_limit=1 )
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-16
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 14191 rows, 12486 columns and 58699 nonzeros
# Model fingerprint: 0x17616faf
# Model has 1 quadratic constraint
# Variable types: 6 continuous, 12480 integer (12480 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 3e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e-03, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve time: 0.03s
# Presolved: 14191 rows, 12486 columns, 58699 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 12483 integer (12480 binary)
#
# Root relaxation: objective 0.000000e+00, 7217 iterations, 0.20 seconds (0.64 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    3          -    0.00000      -     -    0s
#      0     0    0.98372    0 1077          -    0.98372      -     -    1s
#      0     0    1.07587    0 1325          -    1.07587      -     -    1s
#      0     0    1.07982    0 1326          -    1.07982      -     -    1s
#      0     0    1.08709    0 1086          -    1.08709      -     -    2s
#      0     0    1.08787    0 1091          -    1.08787      -     -    2s
#      0     0    1.08860    0 1059          -    1.08860      -     -    3s
#      0     0    1.08866    0 1059          -    1.08866      -     -    3s
#      0     0    1.08866    0 1059          -    1.08866      -     -    3s
#      0     2    1.08890    0 1059          -    1.08890      -     -    4s
#      3     4    1.28350    2 1383          -    1.25608      -   853    5s
#    300   309    4.34477   18  159          -    1.55603      -   540   10s
#   1470  1588    4.62276   56   87          -    1.55603      -   311   15s
#   2930  2836    2.68987   33 1075          -    1.55603      -   226   21s
#   2933  2838    5.75674   82 1071          -    1.55603      -   225   26s
#   2936  2840    1.87554    9 1104          -    1.55603      -   225   31s
#   3063  2928    3.40488   22  978          -    1.79688      -   253   35s
#   3502  3216    3.12972   27 1406          -    1.79688      -   277   40s
# H 4285  3584                       3.0770658    1.79688  41.6%   290   44s
#   4355  3559     cutoff   43         3.07707    1.80258  41.4%   289   46s
# H 4361  3422                       3.0130008    1.80258  40.2%   289   46s
# H 4444  3267                       2.7633563    1.80258  34.8%   287   46s
# H 4634  3092                       2.6800083    1.80258  32.7%   284   48s
#   4841  3028    2.39055   25 1481    2.68001    1.80258  32.7%   282   50s
# H 4842  2912                       2.6085406    1.80258  30.9%   282   50s
# H 4847  2800                       2.5996382    1.80258  30.7%   282   50s
# H 4871  2688                       2.5586142    1.80258  29.5%   282   50s
# H 5259  2395                       2.5501453    2.10708  17.4%   269   52s
#   5745  2352    2.52397   43   22    2.55015    2.44597  4.09%   254   56s
#   6707  1929     cutoff   41         2.55015    2.48692  2.48%   228   61s
#   7735  1655    2.53548   42  158    2.55015    2.50553  1.75%   206   65s
#   8905  1442     cutoff   41         2.55015    2.51380  1.43%   187   70s
# H 9860  1354                       2.5352867    2.51413  0.83%   173   73s
# *10598   373              91       2.5352867    2.51471  0.81%   164   74s
#  11294     0     cutoff   40         2.53529    2.52790  0.29%   155   75s
#
# Cutting planes:
#   Gomory: 5
#   MIR: 15
#   StrongCG: 2
#   Lazy constraints: 5
#
# Explored 11667 nodes (1778253 simplex iterations) in 75.52 seconds (93.72 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 9: 2.53529 2.55015 2.55861 ... 3.07707
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.535286658997e+00, best bound 2.535286658997e+00, gap 0.0000%
#
# User-callback calls 28207, time in user-callback 0.19 sec

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 2.5352866589968017
# The Polsby-Popper score is 0.3944327149166218
#
# District has this many nodes: 390
# And a population of: 717793
# Is it connected? True

# %%
vap = sum( DG.nodes[i]['VAP'] for i in district )
mvap = sum( DG.nodes[i]['MVAP'] for i in district )
print("The total voting age population is:",vap)
print("Among the",minority,"population, the VAP is:",mvap)
print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 564273
# Among the Black population, the VAP is: 282158
# As a percentage, this is 50.0 %

# %%
# Let's draw the district on a map
from export import draw_single_district
G._state = state
G._level = level

# %%
# State-wide view
draw_single_district( G, district, zoom=False )
# Out:
# Exporting to png...

# %%
# District-only view
draw_single_district( G, district, zoom=True )
# Out:
# Exporting to png...

# %%
complement = [ i for i in G.nodes if i not in district ]
print("Is the complement connected?", nx.is_connected(G.subgraph(complement)))
# Out:
# Is the complement connected? True
