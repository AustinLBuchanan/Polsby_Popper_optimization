# %%
# primary settings
state = 'AL'
district_type = 'CD'
level = 'vtd'
deviation = 0.01  # 0.10 means 10% means +/-5%
minority = 'Black'

# %%
filepath = 'C:\\districting-data-2020-reprojection\\'
filename = state + '_' + level + '.json'

from read import read_graph_from_json
G = read_graph_from_json( filepath + filename )
print("number of nodes, edges:",G.number_of_nodes(),G.number_of_edges())
# Out:
# number of nodes, edges: 1837 5221

# %%
from number_of_districts import number_of_districts

k = number_of_districts[state, district_type]
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
L = math.ceil(  ideal_population * (1-deviation/2) )
U = math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 7 714166 721342

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, mvap_excess_penalty=0.0, contiguity='cut', split_counties_limit=1 )
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-16
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 14191 rows, 12486 columns and 58699 nonzeros
# Model fingerprint: 0xeac05322
# Model has 1 quadratic constraint
# Variable types: 6 continuous, 12480 integer (12480 binary)
# Coefficient statistics:
#   Matrix range     [3e-05, 3e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# Presolve time: 0.03s
# Presolved: 14191 rows, 12486 columns, 58699 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 12483 integer (12480 binary)
#
# Root relaxation: objective 0.000000e+00, 7999 iterations, 0.25 seconds (0.81 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.99255    0 1077          -    0.99255      -     -    1s
#      0     0    1.04882    0 1058          -    1.04882      -     -    1s
#      0     0    1.05400    0 1072          -    1.05400      -     -    1s
#      0     0    1.05875    0 1059          -    1.05875      -     -    2s
#      0     0    1.06193    0 1060          -    1.06193      -     -    2s
#      0     0    1.06232    0 1060          -    1.06232      -     -    3s
#      0     2    1.06951    0 1060          -    1.06951      -     -    3s
# H   24    20                       4.2727981    1.47750  65.4%  1110    4s
# H   27    32                       3.7563569    1.47750  60.7%  1110    4s
#     70    54    2.49952    7  778    3.75636    1.73937  53.7%   899    5s
# H  180   140                       2.9634193    1.78631  39.7%   617    6s
# H  189   140                       2.5810074    1.78631  30.8%   604    6s
# H  265    38                       2.5729798    1.81375  29.5%   468    6s
# H  298    31                       2.5729798    1.81375  29.5%   426    6s
# H  302    31                       2.5721161    1.91597  25.5%   427    6s
# H  316    31                       2.5721161    1.91597  25.5%   414    6s
# H  320    31                       2.5692895    1.91597  25.4%   409    6s
# H  321    31                       2.5590485    1.91597  25.1%   408    6s
#    726    37    2.46607    9  720    2.55905    2.32334  9.21%   248   10s
#   2483   157    2.54354   36   73    2.55905    2.52805  1.21%   101   15s
#   4185   448    2.53374   47    7    2.55905    2.53374  0.99%  72.5   20s
#   4801   740    2.54242   63  594    2.55905    2.53374  0.99%  63.2   25s
#   5235   687     cutoff   43         2.55905    2.53886  0.79%  57.9   30s
#   5654   870    2.55485   54  651    2.55905    2.53886  0.79%  53.6   35s
#   6285  1038    2.55892   53   20    2.55905    2.54243  0.65%  48.2   40s
#   6925  1166    2.55896   72   28    2.55905    2.54243  0.65%  43.8   46s
#   7395  1504     cutoff   86         2.55905    2.54653  0.49%  41.0   50s
#   7954  1191     cutoff   66         2.55905    2.54964  0.37%  38.1   55s
#   9350  1187     cutoff   76         2.55905    2.55204  0.27%  32.4   61s
#   9868  1212 infeasible   54         2.55905    2.55316  0.23%  30.7   65s
#  10489  1761 infeasible   64         2.55905    2.55445  0.18%  28.9   71s
#  11295  1770    2.55491   15 1312    2.55905    2.55491  0.16%  26.8   76s
#  11323  1769 infeasible   20         2.55905    2.55491  0.16%  26.8   80s
#  11361  1750    2.55530   24  817    2.55905    2.55491  0.16%  26.7   85s
#  11405  1757    2.55491   29 1450    2.55905    2.55491  0.16%  26.6   90s
#  11475  1762    2.55491   32 1474    2.55905    2.55491  0.16%  26.4   96s
#  11547  1776 infeasible   34         2.55905    2.55491  0.16%  26.3  100s
#  11620  1767 infeasible   33         2.55905    2.55491  0.16%  26.1  106s
#  11693  1746    2.55491   35 1440    2.55905    2.55491  0.16%  25.9  110s
#  11775  1716    2.55840   38 1477    2.55905    2.55491  0.16%  25.8  116s
#  11850  1710 infeasible   39         2.55905    2.55491  0.16%  25.6  120s
#  11929  1682    2.55597   36  638    2.55905    2.55491  0.16%  25.4  125s
#  12055  1652     cutoff   39         2.55905    2.55491  0.16%  25.2  132s
#  12147  1605     cutoff   38         2.55905    2.55491  0.16%  25.0  137s
#  12202  1596     cutoff   43         2.55905    2.55491  0.16%  24.8  140s
#  12307  1553     cutoff   34         2.55905    2.55491  0.16%  24.6  145s
#  12423  1534    2.55894   44 3570    2.55905    2.55491  0.16%  24.4  151s
#  12553  1496     cutoff   45         2.55905    2.55491  0.16%  24.2  157s
#  12622  1476    2.55491   33 1547    2.55905    2.55491  0.16%  24.0  160s
#  12780  1379    2.55754   37 1356    2.55905    2.55491  0.16%  23.7  166s
#  12863  1354    2.55787   38 1219    2.55905    2.55491  0.16%  23.6  170s
#  12936  1319    2.55491   41 1290    2.55905    2.55491  0.16%  23.4  175s
#  13091  1242     cutoff   45         2.55905    2.55491  0.16%  23.2  183s
#  13184  1203    2.55491   41 2398    2.55905    2.55491  0.16%  23.0  186s
#  13356  1117    2.55491   40  274    2.55905    2.55491  0.16%  22.7  192s
#  13425  1092    2.55491   41  620    2.55905    2.55491  0.16%  22.6  195s
#  13552  1033    2.55859   53   86    2.55905    2.55491  0.16%  22.4  200s
#  13669   984 infeasible   72         2.55905    2.55491  0.16%  22.2  205s
#  13767   948 infeasible  100         2.55905    2.55528  0.15%  22.0  211s
#  13813   938 infeasible  117         2.55905    2.55612  0.11%  22.0  215s
#
# Cutting planes:
#   Gomory: 2
#   Lazy constraints: 32
#
# Explored 13881 nodes (327617 simplex iterations) in 218.70 seconds (152.98 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 8: 2.55905 2.56929 2.57212 ... 4.2728
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.559048488215e+00, best bound 2.559048488215e+00, gap 0.0000%
#
# User-callback calls 32633, time in user-callback 2.49 sec

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 2.5590484882153968
# The Polsby-Popper score is 0.3907702431607186
#
# District has this many nodes: 391
# And a population of: 719539
# Is it connected? True

# %%
vap = sum( DG.nodes[i]['VAP'] for i in district )
mvap = sum( DG.nodes[i]['MVAP'] for i in district )
print("The total voting age population is:",vap)
print("Among the",minority,"population, the VAP is:",mvap)
print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 564112
# Among the Black population, the VAP is: 282092
# As a percentage, this is 50.01 %

# %%
# Let's draw the district on a map
from export import draw_single_district
G._state = state
G._level = level

# %%
# State-wide view
draw_single_district( G, district, zoom=False )
# Out:
# Exporting to png...

# %%
# District-only view
draw_single_district( G, district, zoom=True )
# Out:
# Exporting to png...

# %%
complement = [ i for i in G.nodes if i not in district ]
print("Is the complement connected?", nx.is_connected(G.subgraph(complement)))
# Out:
# Is the complement connected? True
