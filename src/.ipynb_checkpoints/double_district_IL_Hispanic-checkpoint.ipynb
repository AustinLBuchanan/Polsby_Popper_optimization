# %%
# primary settings
state = 'IL'
level = 'tract'
deviation = 0.01  # 1.00%

minority = 'Hispanic'
permitted_fips = ['17031','17043'] # only pick from Cook and DuPage Counties

from number_of_districts import congressional_districts_2020
k = congressional_districts_2020[state]

# %%
filepath = 'C:\\districting-data-2020\\'
filename = state + '_' + level + '.json'

from gerrychain import Graph
G = Graph.from_json( filepath + filename )

# total population
for i in G.nodes:
    G.nodes[i]['TOTPOP'] = G.nodes[i]['P0010001']

# %%
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
size = 2 # seek a double district
L = size * math.ceil(  ideal_population * (1-deviation/2) )
U = size * math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 17 1499818 1514890

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from single_district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, permitted_fips=permitted_fips )
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-05-11
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 17463 rows, 20726 columns and 86284 nonzeros
# Model fingerprint: 0xb3f710bb
# Model has 1 quadratic constraint
# Variable types: 5 continuous, 20721 integer (20721 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 1e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+06, 2e+06]
# Presolve removed 9309 rows and 11023 columns
# Presolve time: 0.08s
# Presolved: 8154 rows, 9703 columns, 40243 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 9700 integer (9698 binary)
#
# Root relaxation: objective 0.000000e+00, 1693 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     141.5347776    0.00000   100%     -    0s
# *    0     0               0     141.5347776    0.00000   100%     -    0s
#      0     0    0.45567    0  162  141.53478    0.45567   100%     -    1s
#      0     0    1.29448    0  210  141.53478    1.29448  99.1%     -    2s
# H    0     0                       5.3899886    1.29448  76.0%     -    2s
#      0     0    1.29863    0  215    5.38999    1.29863  75.9%     -    2s
# H    0     0                       1.9474904    1.59391  18.2%     -    3s
#      0     0    1.59391    0  291    1.94749    1.59391  18.2%     -    3s
#      0     0    1.61186    0  302    1.94749    1.61186  17.2%     -    3s
# H    0     0                       1.9370917    1.61186  16.8%     -    4s
#      0     0    1.61191    0  305    1.93709    1.61191  16.8%     -    4s
#      0     0    1.62713    0  302    1.93709    1.62713  16.0%     -    4s
#      0     0    1.62714    0  302    1.93709    1.62714  16.0%     -    4s
#      0     0    1.62744    0  302    1.93709    1.62744  16.0%     -    4s
#      0     0    1.62744    0  302    1.93709    1.62744  16.0%     -    4s
#      0     0    1.62908    0  302    1.93709    1.62908  15.9%     -    4s
#      0     0    1.62911    0  302    1.93709    1.62911  15.9%     -    5s
#      0     0    1.62911    0  302    1.93709    1.62911  15.9%     -    5s
#      0     2    1.63173    0  302    1.93709    1.63173  15.8%     -    6s
# H   31    24                       1.8670117    1.71704  8.03%   496    7s
# H   59    56                       1.8670117    1.71704  8.03%   408    8s
# H   63    56                       1.8523883    1.71704  7.31%   385    8s
# H  137    50                       1.8472517    1.71704  7.05%   223    8s
# H  165    78                       1.8332423    1.71704  6.34%   193    9s
#    306    84    1.82536   18   16    1.83324    1.82393  0.51%   136   10s
# H  483    53                       1.8298623    1.82730  0.14%   103   10s
# *  483    53              26       1.8298623    1.82732  0.14%   103   10s
# *  538     0              26       1.8298614    1.82870  0.06%  94.9   10s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 1
#   Cover: 2
#   MIR: 6
#   RLT: 2
#
# Explored 561 nodes (72166 simplex iterations) in 10.42 seconds (12.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 1.82986 1.83324 1.84725 ... 141.535
#
# Optimal solution found (tolerance 0.00e+00)
# Warning: max constraint violation (5.2394e-07) exceeds tolerance
# Best objective 1.829861410918e+00, best bound 1.829861410918e+00, gap 0.0000%

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 1.829861410917784
# The Polsby-Popper score is 0.5464894740298615
#
# District has this many nodes: 356
# And a population of: 1500282
# Is it connected? True

# %%
try:
    minority
except NameError:
    minority = None

if minority is not None:
    vap = sum( DG.nodes[i]['VAP'] for i in district )
    mvap = sum( DG.nodes[i]['MVAP'] for i in district )
    print("The total voting age population is:",vap)
    print("Among the",minority,"population, the VAP is:",mvap)
    print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 1141405
# Among the Hispanic population, the VAP is: 570726
# As a percentage, this is 50.0 %

# %%
# Let's draw the district on a map
from single_district import draw_single_district
filename = state + '_' + level + '.shp'

# %%
# State-wide view
draw_single_district( filepath, filename, G, district, zoom=False )

# %%
# District-only view
draw_single_district( filepath, filename, G, district, zoom=True )
