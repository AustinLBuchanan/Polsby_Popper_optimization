# %%
# primary settings
state = 'SD'
level = 'tract'
deviation = 0.10  # 10.00%

minority = 'Native'
forbidden_fips = ['46065']
contiguity = 'cut'

k = 35 # number of state senate districts

# %%
filepath = 'C:\\districting-data-2020\\'
filename = state + '_' + level + '.json'

from gerrychain import Graph
G = Graph.from_json( filepath + filename )

# total population
for i in G.nodes:
    G.nodes[i]['TOTPOP'] = G.nodes[i]['P0010001']

# %%
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
size = 3 
L = size * math.ceil(  ideal_population * (1-deviation/2) )
U = size * math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 35 72201 79800

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from single_district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, contiguity=contiguity, forbidden_fips=forbidden_fips )
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-05-11
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1247 rows, 1487 columns and 6226 nonzeros
# Model fingerprint: 0x7e11afe2
# Model has 1 quadratic constraint
# Variable types: 5 continuous, 1482 integer (1482 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 9e+03]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e+04, 8e+04]
# Presolve removed 18 rows and 22 columns
# Presolve time: 0.02s
# Presolved: 1229 rows, 1465 columns, 6128 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 1462 integer (1460 binary)
#
# Root relaxation: objective 0.000000e+00, 94 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    9          -    0.00000      -     -    0s
#      0     0    1.92322    0   58          -    1.92322      -     -    0s
#      0     0    2.13534    0   98          -    2.13534      -     -    0s
#      0     0    2.25720    0   59          -    2.25720      -     -    0s
#      0     0    2.25751    0   60          -    2.25751      -     -    0s
#      0     0    2.26429    0   89          -    2.26429      -     -    0s
#      0     0    2.26992    0   91          -    2.26992      -     -    0s
#      0     0    2.27476    0  104          -    2.27476      -     -    0s
#      0     0    2.27520    0  106          -    2.27520      -     -    0s
#      0     0    2.27653    0  107          -    2.27653      -     -    0s
#      0     0    2.27657    0  107          -    2.27657      -     -    0s
#      0     0    2.27657    0  107          -    2.27657      -     -    0s
#      0     0    2.27657    0  107          -    2.27657      -     -    0s
#      0     0    2.27657    0  107          -    2.27657      -     -    0s
#      0     2    2.27898    0  107          -    2.27898      -     -    0s
#   1078   709    3.71968   42   68          -    2.39191      -  61.0    5s
# * 8310  5265             111       5.5724427    2.42477  56.5%  31.6    7s
# * 8486  5061             115       5.0004888    2.42477  51.5%  31.4    7s
# * 9122  5316             159       4.9623305    2.42597  51.1%  31.5    7s
# * 9283  5221              38       4.7186340    2.42943  48.5%  31.4    7s
# H 9316  1899                       2.9389348    2.42943  17.3%  31.6    7s
# H 9385  1205                       2.7949961    2.43657  12.8%  31.9    8s
# H 9500  1003                       2.7780574    2.44109  12.1%  32.2    8s
# H 9569   443                       2.5042223    2.45017  2.16%  32.3    8s
# *10129     0              24       2.5042223    2.50422  0.00%  31.3    8s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 3
#   MIR: 2
#   StrongCG: 1
#   Flow cover: 10
#   Inf proof: 10
#   Zero half: 2
#   RLT: 12
#   Lazy constraints: 58
#
# Explored 10130 nodes (318141 simplex iterations) in 8.36 seconds (7.44 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 2.50422 2.77806 2.795 ... 5.57244
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 2.504222289826e+00, best bound 2.504222289826e+00, gap 0.0000%
#
# User-callback calls 22215, time in user-callback 0.20 sec

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 2.504222289825577
# The Polsby-Popper score is 0.399325572678954
#
# District has this many nodes: 26
# And a population of: 72325
# Is it connected? True

# %%
try:
    minority
except NameError:
    minority = None

if minority is not None:
    vap = sum( DG.nodes[i]['VAP'] for i in district )
    mvap = sum( DG.nodes[i]['MVAP'] for i in district )
    print("The total voting age population is:",vap)
    print("Among the",minority,"population, the VAP is:",mvap)
    print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 49342
# Among the Native population, the VAP is: 24678
# As a percentage, this is 50.01 %

# %%
# Let's draw the district on a map
from single_district import draw_single_district
filename = state + '_' + level + '.shp'

# %%
# State-wide view
draw_single_district( filepath, filename, G, district, zoom=False )

# %%
# District-only view
draw_single_district( filepath, filename, G, district, zoom=True )

# %%
# examine the components of G - district 

nondistrict = [ i for i in G.nodes if i not in district ]
for component in nx.connected_components(G.subgraph(nondistrict)):
    population = sum( G.nodes[i]['TOTPOP'] for i in component )
    print("\nComponent has this many nodes:",len(component))
    print("This much population:",population)
    print("Which corresponds to this many districts:",population/ideal_population)
    draw_single_district( filepath, filename, G, component, zoom=True )
# Out:
# Component has this many nodes: 171
# This much population: 634384
# Which corresponds to this many districts: 25.041464270126216
#
# Component has this many nodes: 45
# This much population: 179958
# Which corresponds to this many districts: 7.103602592630605
