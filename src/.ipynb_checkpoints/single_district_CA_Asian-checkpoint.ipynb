# %%
# primary settings
state = 'CA'
level = 'tract'
deviation = 0.01  # 1.00%

minority = 'Asian'
permitted_fips = ['06085'] # only pick from Santa Clara County

from number_of_districts import congressional_districts_2020
k = congressional_districts_2020[state]

# %%
filepath = 'C:\\districting-data-2020\\'
filename = state + '_' + level + '.json'

from gerrychain import Graph
G = Graph.from_json( filepath + filename )

# total population
for i in G.nodes:
    G.nodes[i]['TOTPOP'] = G.nodes[i]['P0010001'] 
    
num_sc = sum( 1 for i in G.nodes if G.nodes[i]['GEOID20'][0:5] in permitted_fips )
print("Number of nodes in Santa Clara County:",num_sc)
# Out:
# Number of nodes in Santa Clara County: 408
# C:\Users\buchanan\Anaconda3\lib\site-packages\gerrychain\graph\graph.py:239: UserWarning: Found islands (degree-0 nodes). Indices of islands: {1212}
#   "Found islands (degree-0 nodes). Indices of islands: {}".format(islands)

# %%
ideal_population = sum( G.nodes[i]['TOTPOP'] for i in G.nodes ) / k

import math
L = math.ceil(  ideal_population * (1-deviation/2) )
U = math.floor( ideal_population * (1+deviation/2) )

print("Using k, L, U =",k,L,U)
# Out:
# Using k, L, U = 52 756549 764152

# %%
# bidirected version of graph G
import networkx as nx
DG = nx.DiGraph(G)
DG._L = L
DG._U = U

# %%
# build optimization model to minimize inverse PP score
from single_district import build_single_district_mip 

m = build_single_district_mip( DG, minority=minority, permitted_fips=permitted_fips )
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-05-11
# Set parameter MIPGap to value 0
# Set parameter FeasibilityTol to value 1e-07
# Set parameter IntFeasTol to value 1e-07

# %%
# solve the MISOCP
m.optimize(m._callback)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-4790 CPU @ 3.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 49959 rows, 59086 columns and 245388 nonzeros
# Model fingerprint: 0xa1d0bbab
# Model has 1 quadratic constraint
# Variable types: 5 continuous, 59081 integer (59081 binary)
# Coefficient statistics:
#   Matrix range     [2e-06, 4e+04]
#   QMatrix range    [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e+05, 8e+05]
# Presolve removed 47741 rows and 56462 columns
# Presolve time: 0.07s
# Presolved: 2218 rows, 2624 columns, 10851 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Variable types: 3 continuous, 2621 integer (2619 binary)
#
# Root relaxation: objective 0.000000e+00, 684 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      78.8410355    0.00000   100%     -    0s
# *    0     0               0      78.8410355    0.00000   100%     -    0s
#      0     0    0.35285    0  362   78.84104    0.35285   100%     -    0s
# H    0     0                       7.1114259    0.35285  95.0%     -    0s
# H    0     0                       3.4513585    0.35285  89.8%     -    0s
#      0     0    1.10543    0  366    3.45136    1.10543  68.0%     -    0s
# H    0     0                       2.4846265    1.10543  55.5%     -    0s
#      0     0    1.18467    0  581    2.48463    1.18467  52.3%     -    0s
# H    0     0                       2.4781035    1.25371  49.4%     -    0s
#      0     0    1.27606    0  581    2.47810    1.27606  48.5%     -    1s
#      0     0    1.27606    0  581    2.47810    1.27606  48.5%     -    1s
#      0     0    1.27933    0  581    2.47810    1.27933  48.4%     -    1s
#      0     0    1.35792    0  581    2.47810    1.35792  45.2%     -    1s
#      0     0    1.35792    0  581    2.47810    1.35792  45.2%     -    1s
#      0     2    1.35792    0  581    2.47810    1.35792  45.2%     -    1s
# H   27    32                       2.3643089    1.51670  35.9%   290    1s
# H   29    32                       2.0975649    1.51670  27.7%   277    1s
# H   66    60                       1.8102498    1.54606  14.6%   169    2s
# H   97    85                       1.6906865    1.54606  8.55%   141    2s
# *  131    83              18       1.6905114    1.56347  7.51%   113    2s
# H  179    92                       1.6857368    1.56347  7.25%  95.6    2s
# *  345     0              14       1.6854643    1.68546  0.00%  63.9    2s
#
# Cutting planes:
#   Gomory: 4
#
# Explored 354 nodes (28562 simplex iterations) in 2.39 seconds (2.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.68546 1.68574 1.69051 ... 3.45136
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.685464301969e+00, best bound 1.685464301969e+00, gap 0.0000%

# %%
print("The inverse Polsby-Popper score is",m.objval)
print("The Polsby-Popper score is",1.0/m.objval)

# retrieve the district and its population
district = [ i for i in G.nodes if m._x[i].x > 0.5 ] 
population = sum( G.nodes[i]["TOTPOP"] for i in district )

print("\nDistrict has this many nodes:",len(district))
print("And a population of:",population)
print("Is it connected?",nx.is_connected(G.subgraph(district)))
# Out:
# The inverse Polsby-Popper score is 1.685464301969192
# The Polsby-Popper score is 0.5933083239031892
#
# District has this many nodes: 158
# And a population of: 762459
# Is it connected? True

# %%
try:
    minority
except NameError:
    minority = None

if minority is not None:
    vap = sum( DG.nodes[i]['VAP'] for i in district )
    mvap = sum( DG.nodes[i]['MVAP'] for i in district )
    print("The total voting age population is:",vap)
    print("Among the",minority,"population, the VAP is:",mvap)
    print("As a percentage, this is",round( 100 * mvap / vap, 2 ),"%")
# Out:
# The total voting age population is: 614167
# Among the Asian population, the VAP is: 310072
# As a percentage, this is 50.49 %

# %%
# Let's draw the district on a map
from single_district import draw_single_district
filename = state + '_' + level + '.shp'

# %%
# State-wide view
draw_single_district( filepath, filename, G, district, zoom=False )

# %%
# District-only view
draw_single_district( filepath, filename, G, district, zoom=True )
